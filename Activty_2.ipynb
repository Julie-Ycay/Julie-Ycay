# %% [markdown]
# <a href="https://colab.research.google.com/github/Julie-Ycay/Julie-Ycay/blob/main/Activty_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
import sys 
sys.path.append('../../../')
from helpers import *

# %%
img1_female = plt.imread("/Female_Body5.JPG")
plt.imshow(img1_female)
plt.axis("off")
plt.show()

# %%
img1_color = plt.imread("/Female_Body5.JPG", 1)
plt.imshow(cv2.cvtColor(img1_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cv2.imwrite("img1_color.jpg",img1_color)
# Out:
# True

# %%
img1_grayscale = cv2.imread("/Female_Body5.JPG",0)
plt.imshow(cv2.cvtColor(img1_grayscale, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
img2_male= plt.imread("/M_Genital90.JPG")
plt.imshow(img2_male)
plt.axis("off")
plt.show()

# %%
print(img2_male.dtype)
# Out:
# uint8

# %%
print(img1_female.dtype)
# Out:
# uint8

# %%
cv2.imwrite("grayscale.jpg",img1_original)
# Out:
# True

# %%
img2_grayscale = cv2.imread("//M_Genital90.JPG",0)
img2_original = cv2.imread("/content/M_Genital90.JPG",-1)

# %%
img2_color = plt.imread("/M_Genital90.JPG",1)
plt.imshow(cv2.cvtColor(img2_color, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
img2_grayscale = cv2.imread("/M_Genital90.JPG",0)
plt.imshow(cv2.cvtColor(img2_grayscale, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
