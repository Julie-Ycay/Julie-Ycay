# %% [markdown]
# <a href="https://colab.research.google.com/github/Julie-Ycay/Julie-Ycay/blob/main/Activty_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1_female = cv2.imread("/content/Female_Body5.JPG")
img2_male= cv2.imread("/content/M_Genital90.JPG")

# %%
plt.imshow(img1_female)
plt.axis("off")
plt.show()

# %%
plt.imshow(img2_male)
plt.axis("off")
plt.show()

# %%
img1_color = cv2.imread("/content/Female_Body5.JPG",1)
img1_grayscale = cv2.imread("/content/Female_Body5.JPG",0)
img1_original = cv2.imread("/content/Female_Body5.JPG",-1)

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(img1_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img1_grayscale, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
plt.imshow(cv2.cvtColor(img1_original, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
cv2.imwrite("grayscale.jpg",img1_grayscale)
# Out:
# True

# %%
cv2.imwrite("grayscale.jpg",img1_color)
# Out:
# True

# %%
cv2.imwrite("grayscale.jpg",img1_original)
# Out:
# True

# %%
img2_color = cv2.imread("/content/M_Genital90.JPG",1)
img2_grayscale = cv2.imread("/content/M_Genital90.JPG",0)
img2_original = cv2.imread("/content/M_Genital90.JPG",-1)

# %%
plt.imshow(cv2.cvtColor(img2_original, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
